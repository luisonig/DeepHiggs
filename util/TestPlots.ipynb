# %%
import math
import matplotlib.pyplot as plt

from plot_utils import *

# %%
data = read_csv()

# %%
plt.figure(1, figsize=(10,5))
ax=plt.subplot(1, 2, 1)
ax.set_yscale("log")
plt.plot([i[0] for i in data], [i[7] for i in data], label='S/B')
plt.ylabel('S/B')
plt.xlabel('probability')
#plt.title("Learning rate =" + str(ip.learning_rate))
ax=plt.subplot(1, 2, 2)
ax.set_yscale("log")
plt.plot([i[0] for i in data], [i[8] for i in data], label='S/sqrtB')
plt.ylabel('accuracy')
plt.xlabel('probability')
plt.tight_layout()
plt.show()
